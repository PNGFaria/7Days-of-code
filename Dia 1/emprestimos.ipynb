# %%
import pandas as pd

# %%
dados1 = pd.read_csv('emprestimos-20101.csv')

# %%
dados1
# Out:
#        id_emprestimo codigo_barras                 data_renovacao  \
# 0             709684       L095049                            NaN
# 1             709685       L167050                            NaN
# 2             709686    2006017618  2010/01/26 08:07:01.738000000
# 3             709687       L184117  2010/01/18 11:07:46.470000000
# 4             709684       L095049                            NaN
# ...              ...           ...                            ...
# 95352         919377       C019571                            NaN
# 95353         919379       C019573                            NaN
# 95354         919381       C020714                            NaN
# 95355         919382       C020845                            NaN
# 95356         919431       Y011015                            NaN
#
#                      data_emprestimo                 data_devolucao  \
# 0      2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...

# %%
dados1.query('id_emprestimo == 709684')
# Out:
#    id_emprestimo codigo_barras data_renovacao                data_emprestimo  \
# 0         709684       L095049            NaN  2010/01/04 07:44:10.721000000
# 4         709684       L095049            NaN  2010/01/04 07:44:10.721000000
#
#                   data_devolucao  matricula_ou_siape tipo_vinculo_usuario
# 0  2010/01/05 16:26:12.662000000        2.008023e+09   ALUNO DE GRADUAÇÃO
# 4  2010/01/05 16:26:12.662000000        2.008023e+09   ALUNO DE GRADUAÇÃO

# %%
dados2 = pd.read_csv('emprestimos-20102.csv')

# %%
dados2
# Out:
#         id_emprestimo                codigo_barras  \
# 0              799100  S025602_19/11/2013 10:51:34
# 1              799101                   2008049500
# 2              799102                      X008043
# 3              799103                   2009055438
# 4              799104                      S024636
# ...               ...                          ...
# 100691         920241                   2010049629
# 100692         920242                   2003005918
# 100693         920243                   2008015977
# 100694         920244                      S023356
# 100695         920245                      S024938
#
#                        data_renovacao                data_emprestimo  \
# 0                                 NaN  2010/07/01 07:45:41.111000000
# 1                                 NaN  2010/07/01 08:08:17.690000000
# 2                                 NaN  2010/07/01 08:13:31.574000000
# 3       2010/07/14 18:35:35.042000000  2010/07/01 08:22:46.085000000
# ...

# %%
dados3 = pd.read_csv('emprestimos-20111.csv')

# %%
dados4 = pd.read_csv('emprestimos-20112.csv')

# %%
dados5 = pd.read_csv('emprestimos-20121.csv')

# %%
dados6 = pd.read_csv('emprestimos-20122.csv')

# %%
dados7 = pd.read_csv('emprestimos-20131.csv')

# %%
dados8 = pd.read_csv('emprestimos-20132.csv')

# %%
dados9 = pd.read_csv('emprestimos-20141.csv')

# %%
dados10 = pd.read_csv('emprestimos-20142.csv')

# %%
dados11 = pd.read_csv('emprestimos-20151.csv')

# %%
dados12 = pd.read_csv('emprestimos-20152.csv')

# %%
dados13 = pd.read_csv('emprestimos-20161.csv')

# %%
dados14 = pd.read_csv('emprestimos-20162.csv')

# %%
dados15 = pd.read_csv('emprestimos-20171.csv')

# %%
dados16 = pd.read_csv('emprestimos-20172.csv')

# %%
dados17 = pd.read_csv('emprestimos-20181.csv')

# %%
dados18 = pd.read_csv('emprestimos-20182.csv')

# %%
dados19 = pd.read_csv('emprestimos-20191.csv')

# %%
dados20 = pd.read_csv('emprestimos-20192.csv')

# %%
dados21 = pd.read_csv('emprestimos-20201.csv')

# %%
df = pd.concat([dados1, dados2, dados3, dados4, dados5, dados6, dados7, dados8, dados9, dados10, dados11, dados12, dados13, dados14, dados15, dados16, dados17, dados18, dados19, dados20, dados21], axis = 0)

# %%
df
# Out:
#        id_emprestimo codigo_barras                 data_renovacao  \
# 0             709684       L095049                            NaN
# 1             709685       L167050                            NaN
# 2             709686    2006017618  2010/01/26 08:07:01.738000000
# 3             709687       L184117  2010/01/18 11:07:46.470000000
# 4             709684       L095049                            NaN
# ...              ...           ...                            ...
# 26556        2989086    2008047044                            NaN
# 26557        2989087    2008047047                            NaN
# 26558        2989088    2010052905                            NaN
# 26559        2989089    2010048023                            NaN
# 26560        2989090    2013106838                            NaN
#
#                      data_emprestimo                 data_devolucao  \
# 0      2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...

# %%
parquet = pd.read_parquet('dados_exemplares.parquet')

# %%
parquet
# Out:
#         id_exemplar codigo_barras            colecao  \
# index
# 0                 5       L000003  Acervo Circulante
# 1                 4       L000002  Acervo Circulante
# 2                 3       L000001  Acervo Circulante
# 3                 7       L000114  Acervo Circulante
# 5                10       L000041  Acervo Circulante
# ...             ...           ...                ...
# 568580      1353472    2021011150  Acervo Circulante
# 568581      1353473    2019013454  Acervo Circulante
# 568582      1353474    2019012811  Acervo Circulante
# 568583      1353475    2019013451  Acervo Circulante
# 568584      1353476    2019012276  Acervo Circulante
#
#                                                biblioteca status_material  \
# index
# 0                          Biblioteca Central Zila Mamede         REGULAR
# 1                          Biblioteca Central Zila Mamede         REGULAR
# 2                          Biblioteca Central Zila Mamede        ESPECIAL
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
dfcompleto = df.merge(parquet)

# %%
dfcompleto['biblioteca'].unique()
# Out:
# array(['Biblioteca Central Zila Mamede',
#        'Biblioteca Setorial Prof. Rodolfo Helinski - Escola Agrícola de Jundiaí - EAJ  - Macaiba',
#        'Biblioteca Setorial Bertha Cruz Enders - \xadEscola de Saúde da UFRN - ESUFRN',
#        'Biblioteca Setorial do Centro Ciências da Saúde - CCS',
#        'Biblioteca Setorial Prof. Alberto Moreira Campos - \xadDepartamento de Odontologia',
#        'Biblioteca Setorial Prof. Ronaldo Xavier de Arruda - CCET',
#        'Biblioteca Setorial do Centro de Ciências Humanas, Letras e Artes - CCHLA',
#        'Biblioteca Setorial Prof. Horácio Nicolas Solimo - \xad Engenharia Química - EQ - CT',
#        'Biblioteca Setorial Prof. Francisco Gurgel De Azevedo - Instituto Química - IQ',
#        'Biblioteca Setorial do Centro Ciências Sociais Aplicadas - CCSA',
#        'Biblioteca Setorial do Departamento de Artes - DEART',
#        'Biblioteca Setorial Prof. Dr. Marcelo Bezerra de Melo Tinôco - DARQ - \xadCT',
# ...
